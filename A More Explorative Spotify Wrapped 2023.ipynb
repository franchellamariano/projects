# %% [markdown]
# # A Deeper Dive Into My 2023 Spotify Wrapped
#
# ## Introduction
# In the spirit of reflecting on my music journey, I decided to create an updated version of my Spotify Wrapped for the year 2023. While Spotify Wrapped traditionally provides a comprehensive overview of user listening habits based on data collected from January 1 to early November, I sought to extend the analysis to cover my streaming history until the end of November. This extension allows me to capture a more complete picture of my music preferences and discover any shifts or trends in my listening habits during the later months of the year.
#
# ## Going Beyond the Standard Analysis
# Unlike the Spotify Wrapped feature, which offers a snapshot of the entire year, my personalized analysis delves deeper into the nuances of my music consumption. I explore not only the overarching trends but also my top artists and songs on a monthly basis. This granular approach enables me to identify the artists and songs that resonated with me during specific periods, providing a more detailed and nuanced understanding of my musical preferences.
#
# Moreover, I go beyond the general statistics provided by Spotify Wrapped by examining my music habits at different times of the day. By analyzing my top songs and artists during the morning, afternoon, and night, I gain insights into how my music choices vary based on the mood and activities of each part of the day. This comprehensive exploration enhances my understanding of the role music plays in shaping my daily experiences.
#
# In this updated Spotify Wrapped, I aim to not only celebrate my favorite artists and songs but also to gain a deeper appreciation for the intricacies of my musical journey throughout the year.

# %% [markdown]
# ### Setting Up My Analysis Journey
# To begin, I imported possible libraries that I needed to use, and additionally downloaded my streaming history data courtesy of Spotify.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_json('/kaggle/input/streaming-history/StreamingHistory0.json')
data
# Out:
#                endTime         artistName  \
# 0     2023-08-18 16:10          21 Savage
# 1     2023-08-18 16:13      Bobby Shmurda
# 2     2023-08-18 16:16            Solange
# 3     2023-08-18 16:19          Baby Keem
# 4     2023-08-18 16:23                JID
# ...                ...                ...
# 6396  2023-11-22 22:19     Taylor Bennett
# 6397  2023-11-22 22:26             Weezer
# 6398  2023-11-22 22:32              Lorde
# 6399  2023-11-22 22:36  Twenty One Pilots
# 6400  2023-11-22 23:47  Twenty One Pilots
#
#                                          trackName  msPlayed
# 0                                         No Heart    235040
# 1              Shmoney (feat. Quavo & Rowdy Rebel)    169994
# 2                                           Almeda    177463
# 3                                            STATS    169828
# 4     Surround Sound (feat. 21 Savage & Baby Tate)    229938
# ...                                            ...       ...
# ...

# %% [markdown]
# ### My Total Minutes Played

# %%
sum_of_msPlayed = data['msPlayed'].sum()
sum_of_msPlayed = sum_of_msPlayed / 60000
print(f"Sum of {'msPlayed'}: {sum_of_msPlayed}")
# Out:
# Sum of msPlayed: 8551.1232

# %% [markdown]
# Despite Spotify's Wrapped claiming a total listening time of 7207 minutes, the sum of msPlayed in this extended dataset notably surpasses that figure, totaling approximately 8551 minutes. This, of course, stems from the inclusion of additional data beyond Spotify Wrapped's cutoff date, providing a more accurate and comprehensive representation of my music consumption throughout the year.

# %% [markdown]
# ### My Top 10 Artists

# %%
top_artists = data['artistName'].value_counts().head(10)
result = top_artists
print("Top artists listened to:")
print(result)
# Out:
# Top artists listened to:
# artistName
# Kanye West            404
# Lil Uzi Vert          128
# Travis Scott          120
# Drake                 111
# Playboi Carti         106
# Jean Dawson            95
# Dominic Fike           90
# Tyler, The Creator     84
# Earth, Wind & Fire     81
# Kendrick Lamar         79
# Name: count, dtype: int64

# %% [markdown]
# The analysis of my top 10 artists provides a more detailed perspective on the artists that have prominently shaped my musical experience. Contrary to Spotify Wrapped, which typically showcases the top 5 artists, this extended analysis reveals a broader spectrum of my music preferences.
#
# **Kanye West**: Commanding a significant presence, Kanye West leads the pack, reaffirming his enduring influence on my musical journey. His tracks continue to resonate, solidifying his pivotal role in shaping my musical preferences.
#
# **Lil Uzi Vert, Travis Scott, and Drake**: Maintaining steadfast positions, Lil Uzi Vert, Travis Scott, and Drake exemplify the enduring popularity of contemporary hip-hop within my repertoire. Their collective impact is evident in the substantial playtime garnered by their tracks.
#
# **Playboi Carti and Jean Dawson**: Contributing unique sonic flavors, Playboi Carti and Jean Dawson showcase the breadth of my musical palette. Their distinctive styles add layers of diversity, reflecting my appreciation for a variety of musical expressions.
#
# **Earth, Wind & Fire**: With timeless allure transcending eras, Earth, Wind & Fire's enduring appeal brings a classic touch to my top 10 artists. Their music continues to resonate, highlighting the longevity of their influence.
#
# **Dominic Fike**: In this exploration of my top 10 artists, Dominic Fike emerges as a standout contributor, injecting a unique and diverse musical flair into my listening experience. His inclusion enriches the overall tapestry of genres represented in my top artist list.
#
# **Kendrick Lamar**: Rounding out the top 10, Kendrick Lamar leaves a lasting impression with a compelling musical impact. His inclusion underscores the richness of my musical preferences, offering a glimpse into the depth of my listening experience.

# %% [markdown]
# ### My Top 10 Songs Played
# In scrutinizing the top 10 songs from my music history, a narrative of my listening preferences unfolds, offering a more extensive perspective compared to Spotify Wrapped's usual top 5 songs. Here are key insights into each track:

# %%
top_songs = data['trackName'].value_counts().head(10)
result = top_songs
print("Top songs played:")
print(result)
# Out:
# Top songs played:
# trackName
# September                                 45
# Ghost Town                                38
# SKELETONS                                 20
# nightmares                                19
# Sweat (A La La La La Long)                18
# Va Va Voom                                17
# Lord I Need You                           17
# Violent Crimes                            16
# S.O.S.                                    15
# Money (feat. Juice WRLD & Nicki Minaj)    14
# Name: count, dtype: int64

# %% [markdown]
# **"September"**: Claiming the top spot with an impressive play count of 45, the track "September" by Earth, Wind & Fire stands out as my most listened to song. The recurrent presence of this iconic tune in my daily rotation doesn't come as a surprise, especially considering its heightened playtime when I played it all day on September 21, reflecting a specific day when its resonance was particularly strong.
#
# **"Ghost Town"**: Kanye West's "Ghost Town" secures the second position with a notable play count of 38. Its consistent popularity underscores its enduring appeal, known for its soulful melodies and introspective lyrics about being a father. Unurpringly, I knew that "Ghost Town would be up there due to the fact that it is, in fact, my favorite Kanye West song.
#
# **"SKELETONS"**: Travis Scott's "SKELETONS" with 20 plays establishes itself as a prominent entry in my top 10 songs, known for its dreamy production and collaboration with artists like Pharrell Williams and The Weeknd.
#
# **"nightmares"**: Easy Life's "nightmares" contributes to the diversity of my top 10 with 19 plays, showcasing its significance in my varied musical preferences. Easy Life is known for their eclectic sound that blends indie, pop, and hip-hop elements, making "nightmares" a standout track with its catchy melodies and insightful lyrics.
#
# **"Sweat (A La La La La Long)"**: Inner Circle's reggae classic "Sweat (A La La La La Long)" adds a rhythmic touch to the list with 18 plays, highlighting its consistent playtime and the timeless appeal of reggae music.
#
# **"Va Va Voom" and "Lord I Need You"**: Nicki Minaj's "Va Va Voom" and Kanye West's "Lord I Need You" share a spot with 17 plays each. "Va Va Voom" is known for Nicki Minaj's dynamic rap verses and catchy hooks, while "Lord I Need You" is known for its powerful and spiritual themes, reflecting Kanye West's exploration of faith and personal struggles. Though the two songs are tied with 17 plays each, I find it humorous how the songs are polar opposites, both in it's instrumentals and lyrically.
#
# **"Violent Crimes"**: Kanye West's "Violent Crimes" with 16 plays contributes to the emotional depth of my top 10 songs, known for its introspective exploration of fatherhood and relationships.
#
# **"S.O.S."**: Rihanna's "S.O.S." makes its mark with 15 plays, adding a dynamic element to the collection of my most-played songs. This iconic pop track showcases Rihanna's signature vocals and catchy melodies. Rihanna's influence on pop and R&B is evident in the timeless appeal of "S.O.S.," making it a significant part of my top 10 songs.
#
# **"Money (feat. Juice WRLD & Nicki Minaj)"**: Closing the list, "Money (feat. Juice WRLD & Nicki Minaj)" secures a place with 14 plays. The inclusion of this track is particularly influenced by my admiration for Nicki Minaj's verse, highlighting the significance of artist collaborations in shaping my musical preferences.

# %% [markdown]
# ### My Top 10 Songs that I Listened to the Least
# In examining my least listened to songs, a distinct perspective on tracks that didn't resonate as strongly emerges. It's worth noting that Spotify Wrapped typically highlights the top songs, so this analysis provides insights into the less-played tunes. Here are some observations about the least listened to songs.

# %%
bottom_songs = data['trackName'].value_counts(ascending=True).head(10)
result = bottom_songs
print("Songs that you played the least:")
print(result)
# Out:
# Songs that you played the least:
# trackName
# Place                                   1
# First Person Shooter (feat. J. Cole)    1
# Daylight                                1
# Fear Of Heights                         1
# Calling For You (feat. 21 Savage)       1
# Rocky                                   1
# Ayesha Erotica - Hands Up! (Remix)      1
# Get Like Me                             1
# Salt Shaker                             1
# Doorman                                 1
# Name: count, dtype: int64

# %% [markdown]
# ### My Top 10 Artists that I Listened to the Least
# I also decided to figure out my top 10 artists that I least listened to.

# %%
bottom_artists = data['artistName'].value_counts(ascending=True).head(10)
result = bottom_artists
print("Artists that you listened to the least:")
print(result)
# Out:
# Artists that you listened to the least:
# artistName
# Studio Killers     1
# Orelsan            1
# La Fève            1
# OBOY               1
# Claude François    1
# COIN               1
# Hamza              1
# Aya Nakamura       1
# Lord Huron         1
# Healy              1
# Name: count, dtype: int64

# %% [markdown]
# ### My Top 5 Songs Played in November
# In my quest for a more comprehensive understanding of my music preferences, I delved into the data to uncover my most listened to songs during November. This analysis is prompted by the realization that Spotify Wrapped typically excludes data from the majority of November.

# %%
data['endTime'] = pd.to_datetime(data['endTime'])
fall_songs = data[data['endTime'].dt.month.isin([11])]
song_counts = fall_songs['trackName'].value_counts()
top_songs_fall = song_counts.head(5)
result = top_songs_fall
print("Top songs played during November:")
print(result)
# Out:
# Top songs played during November:
# trackName
# Ghost Town          38
# Lord I Need You     16
# S.O.S.              12
# Pass The Dutchie    11
# Come to Life        10
# Name: count, dtype: int64

# %% [markdown]
# **"Ghost Town" (38 plays)**: Claiming the top spot with an impressive 38 plays, Kanye West's "Ghost Town" emerges as a standout track that dominated my listening experience in November. Its consistent popularity underscores its enduring appeal, making it a noteworthy entry in the list.
#
# **"Lord I Need You" (16 plays)**: Kanye West's "Lord I Need You" secures the second position with 16 plays, showcasing its continued influence on my November playlist.
#
# **"S.O.S." (12 plays)**: Rihanna's "S.O.S." makes its mark with 12 plays, adding a dynamic element to the November playlist.
#
# **"Pass The Dutchie" (11 plays)**: With 11 plays, "Pass The Dutchie" adds a rhythmic touch to the November lineup. This classic reggae track's inclusion signifies its consistent playtime, contributing to the diverse range of genres in my music choices.
#
# **"Come to Life" (10 plays)**: Closing the top 5, Kanye West's "Come to Life" makes its mark with 10 plays, offering a melodic and introspective addition to my November playlist. The track's consistent playtime highlights its resonance during this specific period.
#
# During the month of November, my music landscape was notably shaped by a significant inclination towards Kanye West's discography, particularly gravitating towards his songs that delve into themes of mental health and spirituality. Kanye's artistry has a unique ability to intertwine poignant narratives with soul-stirring melodies, providing a resonant backdrop for moments of introspection and reflection. Tracks such as "Ghost Town" and "Come to Life" stood out as not just musical compositions but as poignant expressions of Kanye's exploration of mental health and spiritual dimensions. This thematic connection added a profound layer to my November playlist, creating a musical journey that transcended mere entertainment and delved into the realm of contemplation.

# %% [markdown]
# ### My Top 5 Songs Played During the Summer
# In an exploration of my musical journey during the summer months, I sought to understand the tracks that resonated with me during this vibrant period. It's worth noting that this analysis covers the months of August and September, encapsulating the essence of summer. Additionally, the summer season marked the start of my new Spotify account, adding an extra layer of curiosity to uncover the musical preferences that defined the beginning of this musical chapter.

# %%
data['endTime'] = pd.to_datetime(data['endTime'])
summer_songs = data[data['endTime'].dt.month.isin([8, 9])]
song_counts = summer_songs['trackName'].value_counts()
top_songs_summer = song_counts.head(5)
result = top_songs_summer
print("Top songs played during the summer:")
print(result)
# Out:
# Top songs played during the summer:
# trackName
# September                                  35
# Love Sosa                                  12
# all-american bitch                         11
# I Don't Wanna Talk (I Just Wanna Dance)    11
# Money (feat. Juice WRLD & Nicki Minaj)     11
# Name: count, dtype: int64

# %% [markdown]
# **"September" (35 plays)**: The classic track "September" by Earth, Wind & Fire takes the lead with an impressive 35 plays. Its timeless melody and upbeat vibes encapsulate the essence of summer, becoming a prominent feature in my playlist.
#
# **"Love Sosa" by Chief Keef (12 plays)**: "Love Sosa" claims a significant spot with 12 plays, adding a hip-hop flair to the summer soundtrack. Chief Keef's energetic delivery and the track's iconic production contributed to its repeated plays during this period.
#
# **"all-american bitch" by Olivia Rodrigo (11 plays)**: The song "all-american bitch" makes its mark with 11 plays, offering a distinct sonic flavor to the summer playlist. Olivia Rodrigo's raw and candid lyrics, coupled with the track's alt-rock influences, create a compelling listening experience.
#
# **"I Don't Wanna Talk (I Just Wanna Dance)" by Glass Animals (11 plays)**: With 11 plays, "I Don't Wanna Talk (I Just Wanna Dance)" by Glass Animals adds a dreamy and danceable element to the summer repertoire. The track's atmospheric production and infectious rhythm make it a standout choice for the season.
#
# **"Money (feat. Juice WRLD & Nicki Minaj)" (11 plays)**: Closing the top 5, "Money" featuring Juice WRLD and Nicki Minaj secures a spot with 11 plays.
#
# A common thread running through these diverse tracks is their ability to evoke feelings of energy, nostalgia, and a carefree spirit—hallmarks of the summer experience. Whether it's the soulful grooves of "September," the street vibes of "Love Sosa," or the indie-pop charm of "all-american bitch," each song contributes to a multifaceted soundtrack that mirrors the dynamic and eclectic nature of summer moments.

# %% [markdown]
# ### My Top 5 Songs that I Listened to the Most at Night
# Spotify Wrapped doesn't provide information about users' nighttime preferences, which prompted me to delve into my own data to uncover these nocturnal musical moments.In an exploration of my nighttime music preferences, I delved into the tracks that resonated with me during the hours of the night by focusing on songs played between 9 PM and 5 AM.

# %%
data['endTime'] = pd.to_datetime(data['endTime'])
night_songs = data[(data['endTime'].dt.hour >= 21) | (data['endTime'].dt.hour < 5)]
song_counts = night_songs['trackName'].value_counts()
top_night_songs = song_counts.head(5)
result = top_night_songs
print("Top songs played during the night:")
print(result)
# Out:
# Top songs played during the night:
# trackName
# Ghost Town        14
# S.O.S.            12
# nightmares         9
# Hold On            8
# Violent Crimes     7
# Name: count, dtype: int64

# %% [markdown]
# **"Ghost Town" by Kanye West (14 plays)**: "Ghost Town" claims the top spot with 14 plays, providing a hauntingly beautiful choice for the tranquil hours of the night. Its soulful melodies and introspective lyrics create a captivating atmosphere during nocturnal listening sessions. The song's poignant themes may have resonated with the quietude of the night.
#
# **"S.O.S." by Rihanna (12 plays)**: Rihanna's "S.O.S." secures a significant position with 12 plays, adding a touch of urgency and rhythm to the night soundtrack. Notably, this track became a regular companion during weekend nights before going out with friends, infusing energy and excitement into the pre-night-out moments.
#
# **"nightmares" by Easy Life (9 plays)**: The track "nightmares" adds a dreamy and contemplative element with 9 plays. Its mellow vibes and thoughtful lyrics contribute to a serene nighttime ambiance, creating a space for reflection.
#
# **"Hold On" by Jonas Brothers (8 plays)**:    Jonas Brothers' "Hold On" makes its mark with 8 plays, standing out as a departure from the soothing and calm tracks in the nighttime playlist. This 2000s rock-pop anthem offers an energetic and upbeat vibe, contributing a dynamic element to the nocturnal ambiance. The track's vibrant instrumentals and lively vocals create a distinctive presence, showcasing diverse musical experiences during the night.
#
#
# **"Violent Crimes" by Kanye West (7 plays)**: Kanye West's "Violent Crimes" closes the top 5 with 7 plays, showcasing the artist's versatility in crafting emotionally resonant tracks. Interestingly, both "Violent Crimes" and "Ghost Town" are recognized as somber songs, suggesting a preference for reflective and melancholic themes during the night.

# %% [markdown]
# ### My Most Played Songs in Each Month
# This detailed analysis not only highlights my musical preferences but also connects the songs to specific experiences and moods. Spotify Wrapped doesn't provide users with their most listened-to songs in each month, making this personalized analysis an invaluable addition to understand the ebb and flow of musical preferences throughout the year.

# %%
def most_played_in_month(data, excluded_artists=None):
    data['endTime'] = pd.to_datetime(data['endTime'])
    data['msPlayed'] = data['msPlayed'] / 60000
    if excluded_artists:
        data = data[~data['artistName'].isin(excluded_artists)]
    monthly_playtime = data.groupby([data['endTime'].dt.year, data['endTime'].dt.month, 'artistName', 'trackName'])['msPlayed'].sum()
    most_played_in_month = monthly_playtime.groupby(level=[0, 1]).idxmax().apply(lambda x: x[3])
    return most_played_in_month
excluded_artists = ['The Tiny Meat Gang Podcast', 'Theo Von Funniest Moments']
result = most_played_in_month(data, excluded_artists)
print("Most played songs in each month:")
print(result)
# Out:
# Most played songs in each month:
# endTime  endTime
# 2023     8                1999 - 2019 Remaster
#          9                           September
#          10         Sweat (A La La La La Long)
#          11                         Ghost Town
# Name: msPlayed, dtype: object

# %% [markdown]
# **August**: August marked the peak of summer vacation, and "1999" by Prince encapsulated the spirit of having fun and carefree enjoyment. The remastered version likely intensified the nostalgia, making it a perfect anthem for my summertime.
#
#
# **September**: Unsurprisingly, Earth, Wind & Fire's "September" claims the top spot in September. Beyond the thematic alignment with the month's title, the mention of "the 21st night of September" adds a serendipitous touch, making it a fitting soundtrack for the month.
#
#
# **October**: "Sweat (A La La La La Long)": October embraced the reggae-infused rhythms of "Sweat (A La La La La Long)." The laid-back vibes of reggae music along with the start of my obsession with reggae during this time provided a pleasant and relaxing auditory experience during this month.
#
#
# **November**: "Ghost Town": In November, the haunting melodies of Kanye West's "Ghost Town" took center stage. The roughness of the my November might have resonated with the introspective and emotionally charged nature of the song, creating a cathartic listening experience.

# %% [markdown]
# ### My Most Played Artists Duirng Each Month
# This thorough examination not only pinpoints my prominent artists but also underscores the significance of album releases, illustrating how major musical events shapeed my monthly listening preferences. Significantly, Spotify Wrapped also lacks the feature to reveal users' most-listened-to artists each month, underscoring the invaluable contribution of this personalized analysis in comprehending the nuanced evolution of musical preferences across time.

# %%
def most_played_artists_per_month(data, excluded_artists=None):
    if excluded_artists:
        data = data[~data['artistName'].isin(excluded_artists)]
    monthly_playtime = data.groupby([data['endTime'].dt.year, data['endTime'].dt.month, 'artistName'])['msPlayed'].sum()
    most_played_artists_per_month = monthly_playtime.groupby(level=[0, 1], group_keys=False).idxmax().apply(lambda x: x[2])
    return most_played_artists_per_month
excluded_artists = ['The Tiny Meat Gang Podcast', 'Theo Von Funniest Moments']
result = most_played_artists_per_month(data, excluded_artists)
print("Most played artists in each month:")
print(result)
# Out:
# Most played artists in each month:
# endTime  endTime
# 2023     8           Travis Scott
#          9          Playboi Carti
#          10                 Drake
#          11            Kanye West
# Name: msPlayed, dtype: object

# %% [markdown]
# **August**: August featured the dynamic sounds of Travis Scott, with the release of his album "Utopia." The album's impact likely contributed to his dominance in my playlist, capturing the essence of the month's musical landscape.
#
# **September**: Playboi Carti's distinct style claimed the spotlight in September. The artist's influence may have contributed to a unique auditory experience, shaping the musical landscape of the month.
#
# **October**: October embraced the multifaceted sounds of Drake, coinciding with the release of his recent album "For All the Dogs." The album's release likely played a significant role in Drake's prominence throughout the month.
#
# **November**: In November, Kanye West unsurprisingly emerged as the most played artist. The artist's emotionally charged tracks, such as "Ghost Town," provided a cathartic outlet during my challenges of the month.

# %% [markdown]
# ### A Timeline of Minutes Played Throughout the Year
# Concluding this overall analysis of my streaming history, I decided to create a timeline to visualize the minutes I spent immersed in music throughout the year.

# %%
data['endTime'] = pd.to_datetime(data['endTime'])
data.set_index('endTime', inplace=True)
ms_played_per_day = data['msPlayed'].resample('D').sum()
plt.figure(figsize=(12, 6))
plt.plot(ms_played_per_day.index, ms_played_per_day.values, marker='o', linestyle='-', color='b')
plt.title('Minutes Played Throughout the Year')
plt.xlabel('Date')
plt.ylabel('Total msPlayed')
plt.grid(axis='both')
plt.show()

# %% [markdown]
# Notably, two standout peaks caught my attention. The first peak, at the midpoint of August, hinted at a significant uptick in music engagement, possibly coinciding with lively summer moments or specific events. The second peak, kicking off October, marked another notable surge in my listening minutes. These peaks serve as interesting indicators, prompting reflection on the tunes that captivated me during these peak times and the reasons behind these shifts in my music habits.

# %% [markdown]
# ## Conclusion: Unveiling Common Themes in My Musical Journey
#
# Delving into the intricacies of my music listening history has unraveled a tapestry woven with common themes that resonate throughout the year. One recurrent theme lies in the seasonal shifts, where songs like "September" echo the transition from summer to fall, capturing the essence of changing atmospheres. The dynamic interplay of energetic tunes during summer peaks and reflective, soulful melodies in the colder months contributes to a musical narrative that mirrors the rhythm of the changing seasons.
#
# **Noteworthy Songs: Melodies that Define Moments**
# Certain songs have emerged as true companions, marking significant moments in my life. "Ghost Town," for instance, became a poignant anthem during a challenging November, serving as a cathartic expression of emotions. These standout tracks transcend mere musical enjoyment; they encapsulate memories, emotions, and the unique stories that unfolded during their resonance, creating a soundtrack to my life.
#
# **Pivotal Artists: The Architects of My Musical Landscape**
# In this musical exploration, certain artists have consistently risen to prominence, acting as architects of my evolving musical landscape. Kanye West, with emotionally charged compositions like "Ghost Town," stood out during times of introspection, providing a sonic backdrop for reflection. Travis Scott's "Utopia" album in August and Drake's "For All the Dogs" in October marked pivotal moments, reflecting the influence of artist-driven events on my listening preferences.
#
# **Evolving Tastes: A Dynamic Playlist Journey**
# Beyond individual songs and artists, the dynamic nature of my playlist reflects an ever-evolving taste in music. From the pulsating beats of Playboi Carti to the introspective verses of Kanye West, the diversity within my musical journey mirrors the multifaceted nature of my own experiences and moods.
#
# In conclusion, this personalized exploration into my musical history serves as more than a mere analysis of listening habits—it is a narrative of emotions, memories, and the vibrant spectrum of life, all encapsulated within the harmonies and rhythms that have shaped my year.
